# %%
from datetime import datetime
start = datetime.now()

# %% [markdown]
# ## Steps 01 to 03>
# 1. Download the customer data set and add it to your “Original Data” folder.
# 2.	Create a new notebook in your “Scripts” folder for part 1 of this task.
# 3.	Import your analysis libraries, as well as your new customer data set as a dataframe.

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# set 'root' directory
ICpath = r'C:\Users\joseh\Instacart Basket Analysis'

# import dataviz libraries
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# import dataset
customers = pd.read_csv(os.path.join(ICpath,'02 Data','Original Data','customers.csv'))

# %%
# review imported dataset
customers
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 0                  3    married  165665
# 1                  0     single   59285
# 2                  2    married   99568
# 3                  0     single   42049
# 4                  1    married   40374
# ...              ...        ...     ...
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095
#
# [206209 rows x 10 columns]

# %% [markdown]
# ## Steps 04 - 05 >
# 4. Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.
# 5.	Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
customers.columns
# Out:
# Index(['user_id', 'First Name', 'Surnam', 'Gender', 'STATE', 'Age',
#        'date_joined', 'n_dependants', 'fam_status', 'income'],
#       dtype='object')

# %% [markdown]
# #### Renaming columns to meaningful names, and all in lowercase

# %%
customers.rename(columns = {'First Name':'first_name' ,
                            'Surnam':'last_name',
                            'Gender':'gender',
                            'STATE':'state',
                            'Age':'age',
                            'n_dependants':'dependants',
                            'fam_status':'marital_status'},
                inplace=True)

# %%
# verify renaming of columns
customers.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'gender', 'state', 'age',
#        'date_joined', 'dependants', 'marital_status', 'income'],
#       dtype='object')

# %%
# verify datatypes
customers.dtypes
# Out:
# user_id            int64
# first_name        object
# last_name         object
# gender            object
# state             object
# age                int64
# date_joined       object
# dependants         int64
# marital_status    object
# income             int64
# dtype: object

# %%
customers.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### No duplicates found

# %%
customers[customers['first_name'].isnull()==True]
# Out:
#         user_id first_name last_name  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         dependants marital_status  income
# 53               2        married   41709
# 73               0         single   82518
# 82               3        married  117099
# 99               1        married  155673
# 105              3        married  151819
# ...            ...            ...     ...
# 206038           3        married   87783
# 206044           2        married  108488
# 206090           1        married   45275
# 206162           0         single   56325
# 206171           2        married   59222
#
# [11259 rows x 10 columns]

# %%
# checking columns with mixed data types
for col in customers.columns.tolist():
  weird = (customers[[col]].applymap(type) != customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers[weird]) > 0:
    print (col)
# Out:
# first_name

# %% [markdown]
# ### the only column with a mixed data type is ```first_name```

# %%
# checking how many entries have valid first_name(s)
name_count = customers['first_name'].value_counts()
total=0
for x in name_count:
    total += x
print(total)
# Out:
# 194950

# %% [markdown]
# #### Since the dataframe has 206,209 rows $=>$ and there are 194,950 valid names. There are 11,259 entries with a different data type or unknown values
#
# #### Further inspection (_see following code cell_) shows the "mixed" data types are due to NaN values (i.e. missing ```first_name```s)

# %%
customers[customers['first_name'].isnull()==True]
# Out:
#         user_id first_name last_name  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         dependants marital_status  income
# 53               2        married   41709
# 73               0         single   82518
# 82               3        married  117099
# 99               1        married  155673
# 105              3        married  151819
# ...            ...            ...     ...
# 206038           3        married   87783
# 206044           2        married  108488
# 206090           1        married   45275
# 206162           0         single   56325
# 206171           2        married   59222
#
# [11259 rows x 10 columns]

# %%
# the best approach is to create a column to flag whether first_name is missing
customers['missing_first_name'] = customers['first_name'].isnull()

# %%
# verifying change made
customers['missing_first_name'].value_counts()
# Out:
# False    194950
# True      11259
# Name: missing_first_name, dtype: int64

# %%
customers.duplicated().sum()
# Out:
# 0

# %%
#making sure there are no duplicate user_id(s)
customers['user_id'].duplicated().sum()
# Out:
# 0

# %%
customers['user_id'].max()
# Out:
# 206209

# %%
customers
# Out:
#         user_id first_name last_name  gender           state  age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         dependants marital_status  income  missing_first_name
# 0                3        married  165665               False
# 1                0         single   59285               False
# 2                2        married   99568               False
# 3                0         single   42049               False
# 4                1        married   40374               False
# ...            ...            ...     ...                 ...
# 206204           1        married  148828               False
# 206205           3        married  168639               False
# 206206           2        married   53374               False
# 206207           1        married   99799               False
# 206208           1        married   57095               False
#
# [206209 rows x 11 columns]

# %% [markdown]
# ## Steps 06 - 07>
# 6.	Combine your customer data with the rest of your prepared Instacart data. (Hint: Make sure the key columns are the same data type!)
# 7.	Ensure your notebook contains logical titles, section headings, and descriptive code comments.

# %%
#import pickle file with most recent updates
# import dataset 
ords_prods_merge = pd.read_pickle(os.path.join(ICpath, '02 Data','Prepared Data','orders_products_aggregated.pkl'))
ords_prods_merge.rename(columns={'order_dow':'order_day_of_week'}, inplace=True)
ords_prods_merge
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  \
# 0                         8                     NaN
# 1                         7                    15.0
# 2                        12                    21.0
# 3                         7                    29.0
# 4                        15                    28.0
# ...                     ...                     ...
# 32404854                 15                     1.0
# 32404855                 11                     3.0
# 32404856                  7                     NaN
# 32404857                  5                    15.0
# 32404858                 14                     NaN
#
#           first_order_from_customer  product_id  add_to_cart_order  reordered  \
# 0                              True         196                  1          0
# 1                             False         196                  1          1
# 2                             False         196                  1          1
# 3                             False         196                  1          1
# 4                             False         196                  1          1
# ...                             ...         ...                ...        ...
# 32404854                      False       43553                  2          1
# 32404855                      False       43553                  2          1
# 32404856                       True       42338                  4          0
# 32404857                      False       42338                 16          1
# 32404858                       True       28818                  8          0
#
#           ... department_id  prices        price_label   busiest_day  \
# 0         ...             7     9.0  Mid-range product  Regular busy
# 1         ...             7     9.0  Mid-range product  Regular busy
# 2         ...             7     9.0  Mid-range product  Regular busy
# 3         ...             7     9.0  Mid-range product    Least busy
# 4         ...             7     9.0  Mid-range product    Least busy
# ...       ...           ...     ...                ...           ...
# 32404854  ...             7     3.7  Low-range product  Regular busy
# 32404855  ...             7     3.7  Low-range product  Regular busy
# 32404856  ...            19     6.9  Mid-range product  Regular busy
# 32404857  ...            19     6.9  Mid-range product  Regular busy
# 32404858  ...            14    10.3  Mid-range product    Least busy
#
#           Busiest_Days busiest_period_of_day max_order      loyalty_flag  \
# 0         regular busy           Most orders        10      New customer
# 1         slowest days        Average orders        10      New customer
# 2         slowest days           Most orders        10      New customer
# 3         slowest days        Average orders        10      New customer
# 4         slowest days           Most orders        10      New customer
# ...                ...                   ...       ...               ...
# 32404854  regular busy           Most orders        31  Regular customer
# 32404855  regular busy           Most orders        31  Regular customer
# 32404856  regular busy        Average orders         3      New customer
# 32404857  slowest days         Fewest orders         3      New customer
# 32404858  slowest days           Most orders        16  Regular customer
#
#           spending_flag   order_frequency_flag
# 0           Low spender  Non-frequent customer
# 1           Low spender  Non-frequent customer
# 2           Low spender  Non-frequent customer
# 3           Low spender  Non-frequent customer
# 4           Low spender  Non-frequent customer
# ...                 ...                    ...
# 32404854    Low spender      Frequent customer
# 32404855    Low spender      Frequent customer
# 32404856    Low spender       Regular customer
# 32404857    Low spender       Regular customer
# 32404858    Low spender       Regular customer
#
# [32404859 rows x 22 columns]

# %%
ords_prods_merge['user_id'].max()
# Out:
# 206209

# %%
customers.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'gender', 'state', 'age',
#        'date_joined', 'dependants', 'marital_status', 'income',
#        'missing_first_name'],
#       dtype='object')

# %% [markdown]
# #### In the dataset ```customers``` we do not need to bring the fields that can identify a person (we need to anonymize)
# * ```age``` -- the issue I see with this is that age is not accurate and it would be best to have the year the person was born
# * ```first_name```
# * ```last_name```
# * ```missing_first_name```
#
# #### On the other hand we can use ```age``` and ```date_joined``` to derive the year of birth considering the age declared at the time of regsitration is relative to the date the user joined. Though the operation YEAR_JOINED - AGE is not 100% accurate it should bring us within 1-2 years provided the declared age was true. Let's see how to do that next

# %%
# removing columns to anonymize data
customers2 = customers.drop(columns=['first_name','last_name','age','missing_first_name'])

# %%
# extract the year (as an integer) in which each user joined InstaCart
year_joined = []
for mmddyyyy in customers2['date_joined']:
    year_joined.append(int( mmddyyyy[-4:]) )

# %%
# derive the birth year (approximate) based on age at the time the user joined
customers2['birth_year'] = year_joined - customers['age']

# %%
# verify the results
customers2
# Out:
#         user_id  gender           state date_joined  dependants  \
# 0         26711  Female        Missouri    1/1/2017           3
# 1         33890  Female      New Mexico    1/1/2017           0
# 2         65803    Male           Idaho    1/1/2017           2
# 3        125935  Female            Iowa    1/1/2017           0
# 4        130797  Female        Maryland    1/1/2017           1
# ...         ...     ...             ...         ...         ...
# 206204   168073  Female  North Carolina    4/1/2020           1
# 206205    49635    Male          Hawaii    4/1/2020           3
# 206206   135902  Female        Missouri    4/1/2020           2
# 206207    81095  Female      California    4/1/2020           1
# 206208    80148  Female        New York    4/1/2020           1
#
#        marital_status  income  birth_year
# 0             married  165665        1969
# 1              single   59285        1981
# 2             married   99568        1982
# 3              single   42049        1977
# 4             married   40374        1991
# ...               ...     ...         ...
# 206204        married  148828        1976
# 206205        married  168639        1958
# 206206        married   53374        1954
# 206207        married   99799        1993
# 206208        married   57095        1965
#
# [206209 rows x 8 columns]

# %%
# what columns do we have in ords_prods_merge
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order',
#        'first_order_from_customer', 'product_id', 'add_to_cart_order',
#        'reordered', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'price_label', 'busiest_day', 'Busiest_Days', 'busiest_period_of_day',
#        'max_order', 'loyalty_flag', 'spending_flag', 'order_frequency_flag'],
#       dtype='object')

# %% [markdown]
# #### It is possible to merge/join the two data sets based on user_id --there's no other common field
# ![Exercise%204.9%20customer%20vs%20ords_prods.jpg](attachment:Exercise%204.9%20customer%20vs%20ords_prods.jpg)

# %%
# checking the number of unique user_id's in ords_prods_merge
(~ords_prods_merge['user_id'].duplicated()).sum()
# Out:
# 206209

# %%
# checking the number of unique user_id's in customers
(~customers2['user_id'].duplicated()).sum()
# Out:
# 206209

# %%
ords_prods_cxs_merge = ords_prods_merge.merge(customers2, on = 'user_id', indicator = True)

# %%
ords_prods_cxs_merge['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#eliminate the extra column used to verify the results of the join/merge
ords_prods_cxs_merge.drop(columns = ['_merge'], inplace = True)

# %%
ords_prods_cxs_merge
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854    156685   106143            26                  4
# 32404855    484769    66343             1                  6
# 32404856   1561557    66343             2                  1
# 32404857    276317    66343             3                  6
# 32404858   2922475    66343             4                  1
#
#           order_hour_of_day  days_since_prior_order  \
# 0                         8                     NaN
# 1                         7                    15.0
# 2                        12                    21.0
# 3                         7                    29.0
# 4                        15                    28.0
# ...                     ...                     ...
# 32404854                 23                     5.0
# 32404855                 11                     NaN
# 32404856                 11                    30.0
# 32404857                 15                    19.0
# 32404858                 12                    30.0
#
#           first_order_from_customer  product_id  add_to_cart_order  reordered  \
# 0                              True         196                  1          0
# 1                             False         196                  1          1
# 2                             False         196                  1          1
# 3                             False         196                  1          1
# 4                             False         196                  1          1
# ...                             ...         ...                ...        ...
# 32404854                      False       19675                  1          1
# 32404855                       True       47210                  1          0
# 32404856                      False       47210                  1          1
# 32404857                      False       47210                  1          1
# 32404858                      False       47210                  1          1
#
#           ...      loyalty_flag  spending_flag   order_frequency_flag  gender  \
# 0         ...      New customer    Low spender  Non-frequent customer  Female
# 1         ...      New customer    Low spender  Non-frequent customer  Female
# 2         ...      New customer    Low spender  Non-frequent customer  Female
# 3         ...      New customer    Low spender  Non-frequent customer  Female
# 4         ...      New customer    Low spender  Non-frequent customer  Female
# ...       ...               ...            ...                    ...     ...
# 32404854  ...  Regular customer   High spender      Frequent customer    Male
# 32404855  ...      New customer    Low spender  Non-frequent customer  Female
# 32404856  ...      New customer    Low spender  Non-frequent customer  Female
# 32404857  ...      New customer    Low spender  Non-frequent customer  Female
# 32404858  ...      New customer    Low spender  Non-frequent customer  Female
#
#               state date_joined dependants marital_status  income birth_year
# 0           Alabama   2/17/2019          3        married   40423       1988
# 1           Alabama   2/17/2019          3        married   40423       1988
# 2           Alabama   2/17/2019          3        married   40423       1988
# 3           Alabama   2/17/2019          3        married   40423       1988
# 4           Alabama   2/17/2019          3        married   40423       1988
# ...             ...         ...        ...            ...     ...        ...
# 32404854     Hawaii   5/26/2017          0         single   53755       1992
# 32404855  Tennessee   9/12/2017          3        married   46151       1995
# 32404856  Tennessee   9/12/2017          3        married   46151       1995
# 32404857  Tennessee   9/12/2017          3        married   46151       1995
# 32404858  Tennessee   9/12/2017          3        married   46151       1995
#
# [32404859 rows x 29 columns]

# %% [markdown]
# ## Steps 08-09>
# 8.	Export this new dataframe as a pickle file so you can continue to use it in the second part of this task.
# 9.	Save your notebook so that you can send it to your tutor for review after completing part 2.

# %%
# export the recently merged dataframe
ords_prods_cxs_merge.to_pickle(os.path.join(ICpath,'02 Data','Prepared Data','orders_products_customers.pkl'))

# %%
# time when notebook finishes
print('time to run notebook: ',datetime.now() - start)
# Out:
# time to run notebook:  0:02:34.407721

# %% [markdown]
# ![Exercise%204.9%20PART01%20evidence%20of%20exported%20file.jpg](attachment:Exercise%204.9%20PART01%20evidence%20of%20exported%20file.jpg)

# %%
customers.shape
# Out:
# (206209, 11)

# %%
customers2.shape
# Out:
# (206209, 8)
